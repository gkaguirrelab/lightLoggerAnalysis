# %% [markdown]
# # Data Pre-Processing Pipeline
# This is a notebook outlining the procedure to go from recordings that are made/downloaded to virtually foveated videos with desired output characteristics

# %% [markdown]
# ## 1. Import Libraries

# %%
import importlib
import preprocessing_pipeline

# %% [markdown]
# ## 2. Generate World Videos from Chunk Recordings

# %% [markdown]
# ### 1. Ensure the world video recordings are renamed properly

# %%
importlib.reload(preprocessing_pipeline)
preprocessing_pipeline.rename_world_recordings(overwrite_existing=False, verbose=True)

# %% [markdown]
# ### 2. Generate the world videos

# %%
importlib.reload(preprocessing_pipeline)
preprocessing_pipeline.generate_world_videos(overwrite_existing=False, verbose=True)

# %% [markdown]
# ## 3. Ensure proper Neon files and matching with World Videos

# %% [markdown]
# ### 1. Ensure downloaded neon files are well formatted and have all required content

# %%
importlib.reload(preprocessing_pipeline)
preprocessing_pipeline.verify_neon_integrity(verbose=True)

# %% [markdown]
# ### 2. Ensure the world videos and neon videos are correctly paired

# %%
importlib.reload(preprocessing_pipeline)
videos_observed: dict[str, dict[str, bool]] = preprocessing_pipeline.verify_world_neon_pairing(verbose=True)

# %% [markdown]
# ## 3. Run Egocentric Video Mapper

# %%
importlib.reload(preprocessing_pipeline)
preprocessing_pipeline.generate_egocentric_mapper_results(overwrite_existing=False, verbose=True)

# %% [markdown]
# ## 4. Virtually Foveate

# %%
importlib.reload(preprocessing_pipeline)
preprocessing_pipeline.generate_virtually_foveated_videos(overwrite_existing=False, verbose=True, activities_to_skip=set(["lunch", "phone"]))

# %%
importlib.reload(preprocessing_pipeline)
preprocessing_pipeline.verify_virtually_foveated_video_integrity(verbose=True, activities_to_skip=["phone", "lunch"])

# %% [markdown]
# ## 5. Generate SPDs

# %% [markdown]
# ### 1. Generate the Indinvidual SPDs and plots for all desired subjects and activitys

# %%
importlib.reload(preprocessing_pipeline)
preprocessing_pipeline.generate_spds(overwrite_existing=False, verbose=True, activities_to_skip=["gazeCalibration", "lunch", "phone"])

# %% [markdown]
# ### 2. Adjust them to a common targeted axis

# %%
importlib.reload(preprocessing_pipeline)
preprocessing_pipeline.adjust_spd_axes(overwrite_existing=True, verbose=True, activities_to_skip=["gazeCalibration", "lunch", "phone"])
# Out:
# Locating project "lightLoggerAnalysis" within "/Users/zacharykelly/Documents/MATLAB/projects".
#   Found at "/Users/zacharykelly/Documents/MATLAB/projects/lightLoggerAnalysis".
# Local copy of ToolboxToolbox is up to date.
# Updating "ToolboxRegistry".
# Already up to date.
# Updating "lightLoggerAnalysis".
# Already up to date.
# Locating project "lightLogger" within "/Users/zacharykelly/Documents/MATLAB/projects".
#   Found at "/Users/zacharykelly/Documents/MATLAB/projects/lightLogger".
# Updating "lightLogger".
# Already up to date.
# Updating "transparentTrack".
# Updating 72ecb8d..f21d01c
# error: Your local changes to the following files would be overwritten by merge:
# 	stages/makeFitVideo.m
# Please commit your changes or stash them before you merge.
# Aborting
# Updating "bads".
# Already up to date.
# Updating "fshift".
# Updating "gkaModelEye".
# Updating 0b5b688..15cabea
# error: Your local changes to the following files would be overwritten by merge:
# 	model/ellipse/eyePoseEllipseFit.m
# Please commit your changes or stash them before you merge.
# Aborting
# Updating "gif".
# Updating "ExampleTestToolbox".
# Already up to date.
# Updating "combiLEDToolbox".
# Already up to date.
# Updating "BrainardLabToolbox".
# Already up to date.
# Updating "WatsonYellott2012_PupilSize".
# Already up to date.
# Updating "export_fig".
# Already up to date.
# Updating "Psychtoolbox-3".
# Already up to date.
# Updating "SilentSubstitutionToolbox".
# Already up to date.
# Resetting path to factory state.
# Adding "ToolboxToolbox" to path at "/Users/zacharykelly/Documents/MATLAB/ToolboxToolbox".
# Adding "lightLoggerAnalysis" to path at "/Users/zacharykelly/Documents/MATLAB/projects/lightLoggerAnalysis".
# Locating project "lightLogger" within "/Users/zacharykelly/Documents/MATLAB/projects".
#   Found at "/Users/zacharykelly/Documents/MATLAB/projects/lightLogger".
# Adding "lightLogger" to path at "/Users/zacharykelly/Documents/MATLAB/projects/lightLogger".
# Adding "transparentTrack" to path at "/Users/zacharykelly/Documents/MATLAB/toolboxes/transparentTrack".
# Adding "bads" to path at "/Users/zacharykelly/Documents/MATLAB/toolboxes/bads".
# Adding "fshift" to path at "/Users/zacharykelly/Documents/MATLAB/toolboxes/matlabcentral/fshift".
# Adding "gkaModelEye" to path at "/Users/zacharykelly/Documents/MATLAB/toolboxes/gkaModelEye".
# Adding "gif" to path at "/Users/zacharykelly/Documents/MATLAB/toolboxes/matlabcentral/gif".
# Adding "ExampleTestToolbox" to path at "/Users/zacharykelly/Documents/MATLAB/toolboxes/ExampleTestToolbox".
# Adding "combiLEDToolbox" to path at "/Users/zacharykelly/Documents/MATLAB/toolboxes/combiLEDToolbox/code".
# Adding "BrainardLabToolbox" to path at "/Users/zacharykelly/Documents/MATLAB/toolboxes/BrainardLabToolbox/LabJackToolbox".
# Adding "BrainardLabToolbox" to path at "/Users/zacharykelly/Documents/MATLAB/toolboxes/BrainardLabToolbox/Plotting".
# Adding "BrainardLabToolbox" to path at "/Users/zacharykelly/Documents/MATLAB/toolboxes/BrainardLabToolbox/OneLiners".
# Adding "BrainardLabToolbox" to path at "/Users/zacharykelly/Documents/MATLAB/toolboxes/BrainardLabToolbox/Overrides".
# Adding "BrainardLabToolbox" to path at "/Users/zacharykelly/Documents/MATLAB/toolboxes/BrainardLabToolbox/OOCalibrationToolbox".
# Adding "WatsonYellott2012_PupilSize" to path at "/Users/zacharykelly/Documents/MATLAB/toolboxes/WatsonYellott2012_PupilSize".
# Adding "export_fig" to path at "/Users/zacharykelly/Documents/MATLAB/toolboxes/export_fig".
# Adding "Psychtoolbox-3" to path at "/Users/zacharykelly/Documents/MATLAB/toolboxes/Psychtoolbox-3/Psychtoolbox".
# Adding "SilentSubstitutionToolbox" to path at "/Users/zacharykelly/Documents/MATLAB/toolboxes/SilentSubstitutionToolbox".
# Checking for "lightLoggerAnalysis" local hook.
#   Running local hook "/Users/zacharykelly/Documents/MATLAB/localHookFolder/lightLoggerAnalysisLocalHook.m".
#   Local hook template more recent than local hook. Consider updating.
# Locating project "lightLoggerAnalysis" within "/Users/zacharykelly/Documents/MATLAB/projects".
#   Found at "/Users/zacharykelly/Documents/MATLAB/projects/lightLoggerAnalysis".
# Locating project "lightLogger" within "/Users/zacharykelly/Documents/MATLAB/projects".
#   Found at "/Users/zacharykelly/Documents/MATLAB/projects/lightLogger".
# Locating project "combiExperiments" within "/Users/zacharykelly/Documents/MATLAB/projects".
#   Found at "/Users/zacharykelly/Documents/MATLAB/projects/combiExperiments".
# Locating project "lightLoggerAnalysis" within "/Users/zacharykelly/Documents/MATLAB/projects".
#   Found at "/Users/zacharykelly/Documents/MATLAB/projects/lightLoggerAnalysis".
#   Hook success with status 0.
# Checking for "lightLogger" local hook.
#   Running local hook "/Users/zacharykelly/Documents/MATLAB/localHookFolder/lightLoggerLocalHook.m".
#   Hook success with status 0.
# Checking for "transparentTrack" local hook.
#   Running local hook "/Users/zacharykelly/Documents/MATLAB/localHookFolder/transparentTrackLocalHook.m".
#   Hook success with status 0.
# Checking for "bads" local hook.
# Checking for "fshift" local hook.
#   Local hook template more recent than local hook. Consider updating.
# Checking for "gkaModelEye" local hook.
#   Running local hook "/Users/zacharykelly/Documents/MATLAB/localHookFolder/gkaModelEyeLocalHook.m".
# Warning: The Matlab Mapping Toolbox is missing. gkaModelEye may not function properly.
# Warning: The Matlab Curve Fitting Toolbox is missing. gkaModelEye may not function properly.
# Warning: The Matlab Optimization Toolbox is missing. gkaModelEye may not function properly.
# Warning: The Matlab Robotics System Toolbox is missing. gkaModelEye may not function properly.
# Warning: The Matlab Statistics and Machine Learning Toolbox is missing. gkaModelEye may not function properly.
# Warning: The Matlab Symbolic Math Toolbox is missing. gkaModelEye may not function properly.
# Warning: The Matlab MATLAB Coder is missing. gkaModelEye may not function properly.
#   Hook success with status 0.
# Checking for "gif" local hook.
# Checking for "ExampleTestToolbox" local hook.
# Checking for "combiLEDToolbox" local hook.
#   Running local hook "/Users/zacharykelly/Documents/MATLAB/localHookFolder/combiLEDToolboxLocalHook.m".
# Warning: The Matlab Optimization Toolbox is missing. combiLEDToolbox may not function properly.
#   Hook success with status 0.
# Checking for "BrainardLabToolbox" local hook.
# Checking for "WatsonYellott2012_PupilSize" local hook.
# Checking for "export_fig" local hook.
# Checking for "Psychtoolbox-3" local hook.
# Checking for "SilentSubstitutionToolbox" local hook.
# Looks good: 14 resolved toolboxes deployed OK.
# Processing Subjects:   0%|          | 0/5 [00:00<?, ?it/s]
# Processing Activities:   0%|          | 0/7 [00:00<?, ?it/s]
# HERE ARE THE CLIM VALS
#    -0.0086    2.0803
#
# HERE ARE THE CLIM VALS
#    -0.0086    2.0803
#
# HERE ARE THE CLIM VALS
#    -0.0086    2.0803
#
# HERE ARE THE CLIM VALS
#    -0.0086    2.0803
#
# HERE ARE THE CLIM VALS
#    -0.0086    2.0803
#
# HERE ARE THE CLIM VALS
#    -0.0086    2.0803
# Processing Activities:   0%|          | 0/7 [00:00<?, ?it/s]
# HERE ARE THE CLIM VALS
#     0.0572    2.0754
#
# HERE ARE THE CLIM VALS
#     0.0572    2.0754
#
# HERE ARE THE CLIM VALS
#     0.0572    2.0754
#
# HERE ARE THE CLIM VALS
#     0.0572    2.0754
#
# HERE ARE THE CLIM VALS
#     0.0572    2.0754
#
# HERE ARE THE CLIM VALS
#     0.0572    2.0754
# Processing Activities:   0%|          | 0/9 [00:00<?, ?it/s]
# HERE ARE THE CLIM VALS
#    -0.0108    2.1788
#
# HERE ARE THE CLIM VALS
#    -0.0108    2.1788
#
# HERE ARE THE CLIM VALS
#    -0.0108    2.1788
#
# HERE ARE THE CLIM VALS
#    -0.0108    2.1788
#
# HERE ARE THE CLIM VALS
#    -0.0108    2.1788
#
# HERE ARE THE CLIM VALS
#    -0.0108    2.1788
# Processing Activities:   0%|          | 0/7 [00:00<?, ?it/s]
# HERE ARE THE CLIM VALS
#     0.2159    2.0038
#
# HERE ARE THE CLIM VALS
#     0.2159    2.0038
#
# HERE ARE THE CLIM VALS
#     0.2159    2.0038
#
# HERE ARE THE CLIM VALS
#     0.2159    2.0038
#
# HERE ARE THE CLIM VALS
#     0.2159    2.0038
#
# HERE ARE THE CLIM VALS
#     0.2159    2.0038
# Processing Activities:   0%|          | 0/6 [00:00<?, ?it/s]
# HERE ARE THE CLIM VALS
#     0.1131    2.0470
#
# HERE ARE THE CLIM VALS
#     0.1131    2.0470
#
# HERE ARE THE CLIM VALS
#     0.1131    2.0470

# %% [markdown]
# ### 3. Generate Per-Subject SPD Plots Grouped by Activity Type (Indoor vs Outdoor)

# %%
importlib.reload(preprocessing_pipeline)
preprocessing_pipeline.group_spds(overwrite_existing=True, verbose=True, subjects_to_skip=[2005], activities_to_skip=["gazeCalibration", "lunch", "phone"])
# Out:
# Locating project "lightLoggerAnalysis" within "/Users/zacharykelly/Documents/MATLAB/projects".
#   Found at "/Users/zacharykelly/Documents/MATLAB/projects/lightLoggerAnalysis".
# Local copy of ToolboxToolbox is up to date.
# Updating "ToolboxRegistry".
# Already up to date.
# Updating "lightLoggerAnalysis".
# Already up to date.
# Locating project "lightLogger" within "/Users/zacharykelly/Documents/MATLAB/projects".
#   Found at "/Users/zacharykelly/Documents/MATLAB/projects/lightLogger".
# Updating "lightLogger".
# Already up to date.
# Updating "transparentTrack".
# Updating 72ecb8d..f21d01c
# error: Your local changes to the following files would be overwritten by merge:
# 	stages/makeFitVideo.m
# Please commit your changes or stash them before you merge.
# Aborting
# Updating "bads".
# Already up to date.
# Updating "fshift".
# Updating "gkaModelEye".
# Updating 0b5b688..15cabea
# error: Your local changes to the following files would be overwritten by merge:
# 	model/ellipse/eyePoseEllipseFit.m
# Please commit your changes or stash them before you merge.
# Aborting
# Updating "gif".
# Updating "ExampleTestToolbox".
# Already up to date.
# Updating "combiLEDToolbox".
# Already up to date.
# Updating "BrainardLabToolbox".
# Already up to date.
# Updating "WatsonYellott2012_PupilSize".
# Already up to date.
# Updating "export_fig".
# Already up to date.
# Updating "Psychtoolbox-3".
# Already up to date.
# Updating "SilentSubstitutionToolbox".
# Already up to date.
# Resetting path to factory state.
# Adding "ToolboxToolbox" to path at "/Users/zacharykelly/Documents/MATLAB/ToolboxToolbox".
# Adding "lightLoggerAnalysis" to path at "/Users/zacharykelly/Documents/MATLAB/projects/lightLoggerAnalysis".
# Locating project "lightLogger" within "/Users/zacharykelly/Documents/MATLAB/projects".
#   Found at "/Users/zacharykelly/Documents/MATLAB/projects/lightLogger".
# Adding "lightLogger" to path at "/Users/zacharykelly/Documents/MATLAB/projects/lightLogger".
# Adding "transparentTrack" to path at "/Users/zacharykelly/Documents/MATLAB/toolboxes/transparentTrack".
# Adding "bads" to path at "/Users/zacharykelly/Documents/MATLAB/toolboxes/bads".
# Adding "fshift" to path at "/Users/zacharykelly/Documents/MATLAB/toolboxes/matlabcentral/fshift".
# Adding "gkaModelEye" to path at "/Users/zacharykelly/Documents/MATLAB/toolboxes/gkaModelEye".
# Adding "gif" to path at "/Users/zacharykelly/Documents/MATLAB/toolboxes/matlabcentral/gif".
# Adding "ExampleTestToolbox" to path at "/Users/zacharykelly/Documents/MATLAB/toolboxes/ExampleTestToolbox".
# Adding "combiLEDToolbox" to path at "/Users/zacharykelly/Documents/MATLAB/toolboxes/combiLEDToolbox/code".
# Adding "BrainardLabToolbox" to path at "/Users/zacharykelly/Documents/MATLAB/toolboxes/BrainardLabToolbox/LabJackToolbox".
# Adding "BrainardLabToolbox" to path at "/Users/zacharykelly/Documents/MATLAB/toolboxes/BrainardLabToolbox/Plotting".
# Adding "BrainardLabToolbox" to path at "/Users/zacharykelly/Documents/MATLAB/toolboxes/BrainardLabToolbox/OneLiners".
# Adding "BrainardLabToolbox" to path at "/Users/zacharykelly/Documents/MATLAB/toolboxes/BrainardLabToolbox/Overrides".
# Adding "BrainardLabToolbox" to path at "/Users/zacharykelly/Documents/MATLAB/toolboxes/BrainardLabToolbox/OOCalibrationToolbox".
# Adding "WatsonYellott2012_PupilSize" to path at "/Users/zacharykelly/Documents/MATLAB/toolboxes/WatsonYellott2012_PupilSize".
# Adding "export_fig" to path at "/Users/zacharykelly/Documents/MATLAB/toolboxes/export_fig".
# Adding "Psychtoolbox-3" to path at "/Users/zacharykelly/Documents/MATLAB/toolboxes/Psychtoolbox-3/Psychtoolbox".
# Adding "SilentSubstitutionToolbox" to path at "/Users/zacharykelly/Documents/MATLAB/toolboxes/SilentSubstitutionToolbox".
# Checking for "lightLoggerAnalysis" local hook.
#   Running local hook "/Users/zacharykelly/Documents/MATLAB/localHookFolder/lightLoggerAnalysisLocalHook.m".
#   Local hook template more recent than local hook. Consider updating.
# Locating project "lightLoggerAnalysis" within "/Users/zacharykelly/Documents/MATLAB/projects".
#   Found at "/Users/zacharykelly/Documents/MATLAB/projects/lightLoggerAnalysis".
# Locating project "lightLogger" within "/Users/zacharykelly/Documents/MATLAB/projects".
#   Found at "/Users/zacharykelly/Documents/MATLAB/projects/lightLogger".
# Locating project "combiExperiments" within "/Users/zacharykelly/Documents/MATLAB/projects".
#   Found at "/Users/zacharykelly/Documents/MATLAB/projects/combiExperiments".
# Locating project "lightLoggerAnalysis" within "/Users/zacharykelly/Documents/MATLAB/projects".
#   Found at "/Users/zacharykelly/Documents/MATLAB/projects/lightLoggerAnalysis".
#   Hook success with status 0.
# Checking for "lightLogger" local hook.
#   Running local hook "/Users/zacharykelly/Documents/MATLAB/localHookFolder/lightLoggerLocalHook.m".
#   Hook success with status 0.
# Checking for "transparentTrack" local hook.
#   Running local hook "/Users/zacharykelly/Documents/MATLAB/localHookFolder/transparentTrackLocalHook.m".
#   Hook success with status 0.
# Checking for "bads" local hook.
#   Local hook template more recent than local hook. Consider updating.
# Checking for "fshift" local hook.
# Checking for "gkaModelEye" local hook.
#   Running local hook "/Users/zacharykelly/Documents/MATLAB/localHookFolder/gkaModelEyeLocalHook.m".
# Warning: The Matlab Mapping Toolbox is missing. gkaModelEye may not function properly.
# Warning: The Matlab Curve Fitting Toolbox is missing. gkaModelEye may not function properly.
# Warning: The Matlab Optimization Toolbox is missing. gkaModelEye may not function properly.
# Warning: The Matlab Robotics System Toolbox is missing. gkaModelEye may not function properly.
# Warning: The Matlab Statistics and Machine Learning Toolbox is missing. gkaModelEye may not function properly.
# Warning: The Matlab Symbolic Math Toolbox is missing. gkaModelEye may not function properly.
# Warning: The Matlab MATLAB Coder is missing. gkaModelEye may not function properly.
#   Hook success with status 0.
# Checking for "gif" local hook.
# Checking for "ExampleTestToolbox" local hook.
# Checking for "combiLEDToolbox" local hook.
#   Running local hook "/Users/zacharykelly/Documents/MATLAB/localHookFolder/combiLEDToolboxLocalHook.m".
# Warning: The Matlab Optimization Toolbox is missing. combiLEDToolbox may not function properly.
#   Hook success with status 0.
# Checking for "BrainardLabToolbox" local hook.
# Checking for "WatsonYellott2012_PupilSize" local hook.
# Checking for "export_fig" local hook.
# Checking for "Psychtoolbox-3" local hook.
# Checking for "SilentSubstitutionToolbox" local hook.
# Looks good: 14 resolved toolboxes deployed OK.
# Processing Subjects:   0%|          | 0/5 [00:00<?, ?it/s]
# Processing Activities:   0%|          | 0/7 [00:00<?, ?it/s]
# HERE ARE THE CLIM VALS
#    -0.0086    2.0803
#
# HERE ARE THE CLIM VALS
#    -0.0086    2.0803
#
# HERE ARE THE CLIM VALS
#    -0.0086    2.0803
#
# HERE ARE THE CLIM VALS
#    -0.0086    2.0803
#
# HERE ARE THE CLIM VALS
#    -0.0086    2.0803
#
# HERE ARE THE CLIM VALS
#    -0.0086    2.0803
# Processing Activities:   0%|          | 0/7 [00:00<?, ?it/s]
# HERE ARE THE CLIM VALS
#     0.0572    2.0754
#
# HERE ARE THE CLIM VALS
#     0.0572    2.0754
#
# HERE ARE THE CLIM VALS
#     0.0572    2.0754
#
# HERE ARE THE CLIM VALS
#     0.0572    2.0754
#
# HERE ARE THE CLIM VALS
#     0.0572    2.0754
#
# HERE ARE THE CLIM VALS
#     0.0572    2.0754
# Processing Activities:   0%|          | 0/9 [00:00<?, ?it/s]
# HERE ARE THE CLIM VALS
#    -0.0108    2.1788
#
# HERE ARE THE CLIM VALS
#    -0.0108    2.1788
#
# HERE ARE THE CLIM VALS
#    -0.0108    2.1788
#
# HERE ARE THE CLIM VALS
#    -0.0108    2.1788
#
# HERE ARE THE CLIM VALS
#    -0.0108    2.1788
#
# HERE ARE THE CLIM VALS
#    -0.0108    2.1788
# Processing Activities:   0%|          | 0/7 [00:00<?, ?it/s]
# HERE ARE THE CLIM VALS
#     0.2159    2.0038
#
# HERE ARE THE CLIM VALS
#     0.2159    2.0038
#
# HERE ARE THE CLIM VALS
#     0.2159    2.0038
#
# HERE ARE THE CLIM VALS
#     0.2159    2.0038
#
# HERE ARE THE CLIM VALS
#     0.2159    2.0038
#
# HERE ARE THE CLIM VALS
#     0.2159    2.0038

# %% [markdown]
# #### 4. Generate SPDs across Subjects per Activity

# %%
importlib.reload(preprocessing_pipeline)
preprocessing_pipeline.generate_spds_across_subject(overwrite_existing=True, verbose=True, subjects_to_skip=[2005], activities_to_skip=["gazeCalibration", "lunch", "phone"], 
                                                    combine_figures=True, common_axes=True)
# Out:
# Locating project "lightLoggerAnalysis" within "/Users/zacharykelly/Documents/MATLAB/projects".
#   Found at "/Users/zacharykelly/Documents/MATLAB/projects/lightLoggerAnalysis".
# Local copy of ToolboxToolbox is up to date.
# Updating "ToolboxRegistry".
# Already up to date.
# Updating "lightLoggerAnalysis".
# Already up to date.
# Locating project "lightLogger" within "/Users/zacharykelly/Documents/MATLAB/projects".
#   Found at "/Users/zacharykelly/Documents/MATLAB/projects/lightLogger".
# Updating "lightLogger".
# Already up to date.
# Updating "transparentTrack".
# Updating 72ecb8d..f21d01c
# error: Your local changes to the following files would be overwritten by merge:
# 	stages/makeFitVideo.m
# Please commit your changes or stash them before you merge.
# Aborting
# Updating "bads".
# Already up to date.
# Updating "fshift".
# Updating "gkaModelEye".
# Updating 0b5b688..15cabea
# error: Your local changes to the following files would be overwritten by merge:
# 	model/ellipse/eyePoseEllipseFit.m
# Please commit your changes or stash them before you merge.
# Aborting
# Updating "gif".
# Updating "ExampleTestToolbox".
# Already up to date.
# Updating "combiLEDToolbox".
# Already up to date.
# Updating "BrainardLabToolbox".
# Already up to date.
# Updating "WatsonYellott2012_PupilSize".
# Already up to date.
# Updating "export_fig".
# Already up to date.
# Updating "Psychtoolbox-3".
# Already up to date.
# Updating "SilentSubstitutionToolbox".
# Already up to date.
# Resetting path to factory state.
# Adding "ToolboxToolbox" to path at "/Users/zacharykelly/Documents/MATLAB/ToolboxToolbox".
# Adding "lightLoggerAnalysis" to path at "/Users/zacharykelly/Documents/MATLAB/projects/lightLoggerAnalysis".
# Locating project "lightLogger" within "/Users/zacharykelly/Documents/MATLAB/projects".
#   Found at "/Users/zacharykelly/Documents/MATLAB/projects/lightLogger".
# Adding "lightLogger" to path at "/Users/zacharykelly/Documents/MATLAB/projects/lightLogger".
# Adding "transparentTrack" to path at "/Users/zacharykelly/Documents/MATLAB/toolboxes/transparentTrack".
# Adding "bads" to path at "/Users/zacharykelly/Documents/MATLAB/toolboxes/bads".
# Adding "fshift" to path at "/Users/zacharykelly/Documents/MATLAB/toolboxes/matlabcentral/fshift".
# Adding "gkaModelEye" to path at "/Users/zacharykelly/Documents/MATLAB/toolboxes/gkaModelEye".
# Adding "gif" to path at "/Users/zacharykelly/Documents/MATLAB/toolboxes/matlabcentral/gif".
# Adding "ExampleTestToolbox" to path at "/Users/zacharykelly/Documents/MATLAB/toolboxes/ExampleTestToolbox".
# Adding "combiLEDToolbox" to path at "/Users/zacharykelly/Documents/MATLAB/toolboxes/combiLEDToolbox/code".
# Adding "BrainardLabToolbox" to path at "/Users/zacharykelly/Documents/MATLAB/toolboxes/BrainardLabToolbox/LabJackToolbox".
# Adding "BrainardLabToolbox" to path at "/Users/zacharykelly/Documents/MATLAB/toolboxes/BrainardLabToolbox/Plotting".
# Adding "BrainardLabToolbox" to path at "/Users/zacharykelly/Documents/MATLAB/toolboxes/BrainardLabToolbox/OneLiners".
# Adding "BrainardLabToolbox" to path at "/Users/zacharykelly/Documents/MATLAB/toolboxes/BrainardLabToolbox/Overrides".
# Adding "BrainardLabToolbox" to path at "/Users/zacharykelly/Documents/MATLAB/toolboxes/BrainardLabToolbox/OOCalibrationToolbox".
# Adding "WatsonYellott2012_PupilSize" to path at "/Users/zacharykelly/Documents/MATLAB/toolboxes/WatsonYellott2012_PupilSize".
# Adding "export_fig" to path at "/Users/zacharykelly/Documents/MATLAB/toolboxes/export_fig".
# Adding "Psychtoolbox-3" to path at "/Users/zacharykelly/Documents/MATLAB/toolboxes/Psychtoolbox-3/Psychtoolbox".
# Adding "SilentSubstitutionToolbox" to path at "/Users/zacharykelly/Documents/MATLAB/toolboxes/SilentSubstitutionToolbox".
# Checking for "lightLoggerAnalysis" local hook.
#   Running local hook "/Users/zacharykelly/Documents/MATLAB/localHookFolder/lightLoggerAnalysisLocalHook.m".
#   Local hook template more recent than local hook. Consider updating.
# Locating project "lightLoggerAnalysis" within "/Users/zacharykelly/Documents/MATLAB/projects".
#   Found at "/Users/zacharykelly/Documents/MATLAB/projects/lightLoggerAnalysis".
# Locating project "lightLogger" within "/Users/zacharykelly/Documents/MATLAB/projects".
#   Found at "/Users/zacharykelly/Documents/MATLAB/projects/lightLogger".
# Locating project "combiExperiments" within "/Users/zacharykelly/Documents/MATLAB/projects".
#   Found at "/Users/zacharykelly/Documents/MATLAB/projects/combiExperiments".
# Locating project "lightLoggerAnalysis" within "/Users/zacharykelly/Documents/MATLAB/projects".
#   Found at "/Users/zacharykelly/Documents/MATLAB/projects/lightLoggerAnalysis".
#   Hook success with status 0.
# Checking for "lightLogger" local hook.
#   Running local hook "/Users/zacharykelly/Documents/MATLAB/localHookFolder/lightLoggerLocalHook.m".
#   Hook success with status 0.
# Checking for "transparentTrack" local hook.
#   Running local hook "/Users/zacharykelly/Documents/MATLAB/localHookFolder/transparentTrackLocalHook.m".
#   Hook success with status 0.
# Checking for "bads" local hook.
# Checking for "fshift" local hook.
#   Local hook template more recent than local hook. Consider updating.
# Checking for "gkaModelEye" local hook.
#   Running local hook "/Users/zacharykelly/Documents/MATLAB/localHookFolder/gkaModelEyeLocalHook.m".
# Warning: The Matlab Mapping Toolbox is missing. gkaModelEye may not function properly.
# Warning: The Matlab Curve Fitting Toolbox is missing. gkaModelEye may not function properly.
# Warning: The Matlab Optimization Toolbox is missing. gkaModelEye may not function properly.
# Warning: The Matlab Robotics System Toolbox is missing. gkaModelEye may not function properly.
# Warning: The Matlab Statistics and Machine Learning Toolbox is missing. gkaModelEye may not function properly.
# Warning: The Matlab Symbolic Math Toolbox is missing. gkaModelEye may not function properly.
# Warning: The Matlab MATLAB Coder is missing. gkaModelEye may not function properly.
#   Hook success with status 0.
# Checking for "gif" local hook.
# Checking for "ExampleTestToolbox" local hook.
# Checking for "combiLEDToolbox" local hook.
#   Running local hook "/Users/zacharykelly/Documents/MATLAB/localHookFolder/combiLEDToolboxLocalHook.m".
# Warning: The Matlab Optimization Toolbox is missing. combiLEDToolbox may not function properly.
#   Hook success with status 0.
# Checking for "BrainardLabToolbox" local hook.
# Checking for "WatsonYellott2012_PupilSize" local hook.
# Checking for "export_fig" local hook.
# Checking for "Psychtoolbox-3" local hook.
# Checking for "SilentSubstitutionToolbox" local hook.
# Looks good: 14 resolved toolboxes deployed OK.
# FLIC_2001 | chat | virtuallyFoveated | exponentMap | [0.880510208467205, 1.7687009396326734]
# FLIC_2001 | chat | virtuallyFoveated | varianceMap | [0.0016220913275541583, 0.1422119109595269]
# FLIC_2001 | chat | virtuallyFoveated | spdByRegion | [3.455388052884536e-09, 0.14997524633502232]
# FLIC_2001 | chat | virtuallyFoveated | frq | [1.0, 59.0]
# FLIC_2001 | chat | justProjection | exponentMap | [-0.008607142426345615, 1.8302267455903671]
# FLIC_2001 | chat | justProjection | varianceMap | [9.219546874727745e-09, 0.13956306722788883]
# FLIC_2001 | chat | justProjection | spdByRegion | [0.0, 0.1479207907280108]
# FLIC_2001 | chat | justProjection | frq | [1.0, 59.0]
# FLIC_2002 | chat | virtuallyFoveated | exponentMap | [0.6214392385234322, 1.6550577566872]
# FLIC_2002 | chat | virtuallyFoveated | varianceMap | [0.0038548102469864874, 0.10913514504115343]
# FLIC_2002 | chat | virtuallyFoveated | spdByRegion | [9.880283441628248e-08, 0.09532543602832538]
# FLIC_2002 | chat | virtuallyFoveated | frq | [1.0, 59.0]
# FLIC_2002 | chat | justProjection | exponentMap | [0.1957765758704409, 1.9268358403013428]
# FLIC_2002 | chat | justProjection | varianceMap | [5.411691066050825e-07, 0.11373452678589256]
# FLIC_2002 | chat | justProjection | spdByRegion | [0.0, 0.09531477165094017]
# FLIC_2002 | chat | justProjection | frq | [1.0, 59.0]
# FLIC_2003 | chat | virtuallyFoveated | exponentMap | [0.42497470543913124, 1.588691958867854]
# FLIC_2003 | chat | virtuallyFoveated | varianceMap | [0.004040124763964943, 0.10043357362404128]
# FLIC_2003 | chat | virtuallyFoveated | spdByRegion | [1.213776281083884e-06, 0.08953395360269983]
# FLIC_2003 | chat | virtuallyFoveated | frq | [1.0, 59.0]
# FLIC_2003 | chat | justProjection | exponentMap | [0.2599767315364278, 1.8887841837978572]
# FLIC_2003 | chat | justProjection | varianceMap | [5.40148066293009e-09, 0.10075244739976157]
# FLIC_2003 | chat | justProjection | spdByRegion | [0.0, 0.0935224612977267]
# FLIC_2003 | chat | justProjection | frq | [1.0, 59.0]
# FLIC_2004 | chat | virtuallyFoveated | exponentMap | [1.056817073839792, 1.7461584316969652]
# FLIC_2004 | chat | virtuallyFoveated | varianceMap | [0.004176708345178113, 0.14916389901558097]
# FLIC_2004 | chat | virtuallyFoveated | spdByRegion | [3.254498078513213e-07, 0.11834350598164951]
# FLIC_2004 | chat | virtuallyFoveated | frq | [1.0, 59.0]
# FLIC_2004 | chat | justProjection | exponentMap | [0.2159176772301293, 1.914325105698634]
# FLIC_2004 | chat | justProjection | varianceMap | [1.2440344408530416e-07, 0.19187630469767059]
# FLIC_2004 | chat | justProjection | spdByRegion | [0.0, 0.1213455155711305]
# FLIC_2004 | chat | justProjection | frq | [1.0, 59.0]
# FLIC_2001 | sitBiopond | virtuallyFoveated | exponentMap | [0.6822374364928301, 1.472807761163191]
# FLIC_2001 | sitBiopond | virtuallyFoveated | varianceMap | [0.0003545888065799349, 0.17301615356893266]
# FLIC_2001 | sitBiopond | virtuallyFoveated | spdByRegion | [4.641345583240164e-08, 0.1336397104379146]
# FLIC_2001 | sitBiopond | virtuallyFoveated | frq | [1.0, 59.0]
# FLIC_2001 | sitBiopond | justProjection | exponentMap | [2.6665090711351343e-15, 1.7922626088348332]
# FLIC_2001 | sitBiopond | justProjection | varianceMap | [4.806909709696955e-09, 0.2395950459163529]
# FLIC_2001 | sitBiopond | justProjection | spdByRegion | [0.0, 0.1613176417334105]
# FLIC_2001 | sitBiopond | justProjection | frq | [1.0, 59.0]
# FLIC_2002 | sitBiopond | virtuallyFoveated | exponentMap | [0.8326095054803188, 1.7877060410079209]
# FLIC_2002 | sitBiopond | virtuallyFoveated | varianceMap | [0.002859908632580018, 0.22723431164246186]
# FLIC_2002 | sitBiopond | virtuallyFoveated | spdByRegion | [1.5121176217582207e-07, 0.1788744779724783]
# FLIC_2002 | sitBiopond | virtuallyFoveated | frq | [1.0, 59.0]
# FLIC_2002 | sitBiopond | justProjection | exponentMap | [0.923766975681991, 1.8432269117553237]
# FLIC_2002 | sitBiopond | justProjection | varianceMap | [2.0159534265616098e-07, 0.3260142453941677]
# FLIC_2002 | sitBiopond | justProjection | spdByRegion | [0.0, 0.20466369603110277]
# FLIC_2002 | sitBiopond | justProjection | frq | [1.0, 59.0]
# FLIC_2003 | sitBiopond | virtuallyFoveated | exponentMap | [0.6599958743476221, 1.7994234564127756]
# FLIC_2003 | sitBiopond | virtuallyFoveated | varianceMap | [0.0015785070786636162, 0.2615730307697743]
# FLIC_2003 | sitBiopond | virtuallyFoveated | spdByRegion | [2.1375238936284095e-08, 0.173037348552553]
# FLIC_2003 | sitBiopond | virtuallyFoveated | frq | [1.0, 59.0]
# FLIC_2003 | sitBiopond | justProjection | exponentMap | [0.3892187338421277, 1.9339523997612045]
# FLIC_2003 | sitBiopond | justProjection | varianceMap | [1.0387687434529877e-08, 0.22723103905731307]
# FLIC_2003 | sitBiopond | justProjection | spdByRegion | [0.0, 0.1611881862540959]
# FLIC_2003 | sitBiopond | justProjection | frq | [1.0, 59.0]
# FLIC_2004 | sitBiopond | virtuallyFoveated | exponentMap | [0.8522634543010622, 1.568318614645722]
# FLIC_2004 | sitBiopond | virtuallyFoveated | varianceMap | [0.00086652712584105, 0.19277697784403677]
# FLIC_2004 | sitBiopond | virtuallyFoveated | spdByRegion | [1.4768068106977925e-07, 0.14754521329029455]
# FLIC_2004 | sitBiopond | virtuallyFoveated | frq | [1.0, 59.0]
# FLIC_2004 | sitBiopond | justProjection | exponentMap | [0.5351719445056037, 1.8914704784571155]
# FLIC_2004 | sitBiopond | justProjection | varianceMap | [1.0419383698242385e-07, 0.25400910778822644]
# FLIC_2004 | sitBiopond | justProjection | spdByRegion | [0.0, 0.2037188693260868]
# FLIC_2004 | sitBiopond | justProjection | frq | [1.0, 59.0]
# FLIC_2001 | walkBiopond | virtuallyFoveated | exponentMap | [1.282870823544102, 1.8719661347098622]
# FLIC_2001 | walkBiopond | virtuallyFoveated | varianceMap | [0.006528098534590635, 0.2397391759549572]
# FLIC_2001 | walkBiopond | virtuallyFoveated | spdByRegion | [1.3161771894344772e-06, 0.16009962932364752]
# FLIC_2001 | walkBiopond | virtuallyFoveated | frq | [1.0, 59.0]
# FLIC_2001 | walkBiopond | justProjection | exponentMap | [-5.544987053647517e-16, 2.0802614894128784]
# FLIC_2001 | walkBiopond | justProjection | varianceMap | [1.158166971197947e-09, 0.25820915996856797]
# FLIC_2001 | walkBiopond | justProjection | spdByRegion | [0.0, 0.16682517371086894]
# FLIC_2001 | walkBiopond | justProjection | frq | [1.0, 59.0]
# FLIC_2002 | walkBiopond | virtuallyFoveated | exponentMap | [1.1199583280562748, 1.7956837545648394]
# FLIC_2002 | walkBiopond | virtuallyFoveated | varianceMap | [0.012200858716665406, 0.26959041848754534]
# FLIC_2002 | walkBiopond | virtuallyFoveated | spdByRegion | [1.2152971435123596e-06, 0.15517694134439708]
# FLIC_2002 | walkBiopond | virtuallyFoveated | frq | [1.0, 59.0]
# FLIC_2002 | walkBiopond | justProjection | exponentMap | [0.0875239595548731, 1.993499670084082]
# FLIC_2002 | walkBiopond | justProjection | varianceMap | [1.9717442268195295e-09, 0.35288982203190394]
# FLIC_2002 | walkBiopond | justProjection | spdByRegion | [0.0, 0.21083124029277103]
# FLIC_2002 | walkBiopond | justProjection | frq | [1.0, 59.0]
# FLIC_2003 | walkBiopond | virtuallyFoveated | exponentMap | [1.0238796508427572, 1.8841459247735104]
# FLIC_2003 | walkBiopond | virtuallyFoveated | varianceMap | [0.012241376386056718, 0.2567448997371401]
# FLIC_2003 | walkBiopond | virtuallyFoveated | spdByRegion | [7.953149329141634e-07, 0.1422670053656637]
# FLIC_2003 | walkBiopond | virtuallyFoveated | frq | [1.0, 59.0]
# FLIC_2003 | walkBiopond | justProjection | exponentMap | [0.8163971914792837, 2.1787997778661485]
# FLIC_2003 | walkBiopond | justProjection | varianceMap | [1.0988722783251095e-06, 0.23079499049954777]
# FLIC_2003 | walkBiopond | justProjection | spdByRegion | [0.0, 0.14605999811526976]
# FLIC_2003 | walkBiopond | justProjection | frq | [1.0, 59.0]
# FLIC_2004 | walkBiopond | virtuallyFoveated | exponentMap | [1.355087051254535, 1.787835602405566]
# FLIC_2004 | walkBiopond | virtuallyFoveated | varianceMap | [0.023574407552683266, 0.2680381741557027]
# FLIC_2004 | walkBiopond | virtuallyFoveated | spdByRegion | [5.77803215156028e-06, 0.1646819480925584]
# FLIC_2004 | walkBiopond | virtuallyFoveated | frq | [1.0, 59.0]
# FLIC_2004 | walkBiopond | justProjection | exponentMap | [0.36799486498936185, 1.9017594182991624]
# FLIC_2004 | walkBiopond | justProjection | varianceMap | [2.069620265422454e-07, 0.38895415099316033]
# FLIC_2004 | walkBiopond | justProjection | spdByRegion | [0.0, 0.20351785406700748]
# FLIC_2004 | walkBiopond | justProjection | frq | [1.0, 59.0]
# FLIC_2001 | walkIndoor | virtuallyFoveated | exponentMap | [1.2559611896834373, 1.852511709071884]
# FLIC_2001 | walkIndoor | virtuallyFoveated | varianceMap | [0.0067578685462252215, 0.12312821794187832]
# FLIC_2001 | walkIndoor | virtuallyFoveated | spdByRegion | [2.091427781636439e-06, 0.1026589537113324]
# FLIC_2001 | walkIndoor | virtuallyFoveated | frq | [1.0, 59.0]
# FLIC_2001 | walkIndoor | justProjection | exponentMap | [1.0524086287125837e-15, 1.980325484212606]
# FLIC_2001 | walkIndoor | justProjection | varianceMap | [1.042363336459316e-08, 0.12675211758461635]
# FLIC_2001 | walkIndoor | justProjection | spdByRegion | [0.0, 0.10474552670105655]
# FLIC_2001 | walkIndoor | justProjection | frq | [1.0, 59.0]
# FLIC_2002 | walkIndoor | virtuallyFoveated | exponentMap | [1.2588628616544026, 1.8114406716956053]
# FLIC_2002 | walkIndoor | virtuallyFoveated | varianceMap | [0.030534432339772894, 0.13481843137382415]
# FLIC_2002 | walkIndoor | virtuallyFoveated | spdByRegion | [9.3664503923638e-06, 0.10546872838682154]
# FLIC_2002 | walkIndoor | virtuallyFoveated | frq | [1.0, 59.0]
# FLIC_2002 | walkIndoor | justProjection | exponentMap | [0.392550140332167, 2.0122229185376623]
# FLIC_2002 | walkIndoor | justProjection | varianceMap | [3.911498890143464e-08, 0.15087444052853505]
# FLIC_2002 | walkIndoor | justProjection | spdByRegion | [0.0, 0.10823856608633553]
# FLIC_2002 | walkIndoor | justProjection | frq | [1.0, 59.0]
# FLIC_2003 | walkIndoor | virtuallyFoveated | exponentMap | [0.5160452240043532, 1.873768914227489]
# FLIC_2003 | walkIndoor | virtuallyFoveated | varianceMap | [0.0003911207144274616, 0.0971445357216376]
# FLIC_2003 | walkIndoor | virtuallyFoveated | spdByRegion | [4.534438994063169e-08, 0.08380656771041481]
# FLIC_2003 | walkIndoor | virtuallyFoveated | frq | [1.0, 59.0]
# FLIC_2003 | walkIndoor | justProjection | exponentMap | [0.4779419965979857, 2.031172460355095]
# FLIC_2003 | walkIndoor | justProjection | varianceMap | [1.148284786452801e-07, 0.09262136391142287]
# FLIC_2003 | walkIndoor | justProjection | spdByRegion | [0.0, 0.08169772430398277]
# FLIC_2003 | walkIndoor | justProjection | frq | [1.0, 59.0]
# FLIC_2004 | walkIndoor | virtuallyFoveated | exponentMap | [1.4232846043435645, 1.8561835277090712]
# FLIC_2004 | walkIndoor | virtuallyFoveated | varianceMap | [0.016956871229962065, 0.13763414075314784]
# FLIC_2004 | walkIndoor | virtuallyFoveated | spdByRegion | [6.289241700543553e-06, 0.10471280993126879]
# FLIC_2004 | walkIndoor | virtuallyFoveated | frq | [1.0, 59.0]
# FLIC_2004 | walkIndoor | justProjection | exponentMap | [0.48499914636761843, 2.0037555464275445]
# FLIC_2004 | walkIndoor | justProjection | varianceMap | [1.7121120235948204e-06, 0.19858256851691314]
# FLIC_2004 | walkIndoor | justProjection | spdByRegion | [0.0, 0.10336541384835707]
# FLIC_2004 | walkIndoor | justProjection | frq | [1.0, 59.0]
# FLIC_2001 | walkOutdoor | virtuallyFoveated | exponentMap | [0.984823253938503, 1.8011721078438048]
# FLIC_2001 | walkOutdoor | virtuallyFoveated | varianceMap | [0.002903356906178223, 0.4125112666737803]
# FLIC_2001 | walkOutdoor | virtuallyFoveated | spdByRegion | [1.034230565798003e-06, 0.31600889295871304]
# FLIC_2001 | walkOutdoor | virtuallyFoveated | frq | [1.0, 59.0]
# FLIC_2001 | walkOutdoor | justProjection | exponentMap | [0.4500674491503064, 1.9048856578390414]
# FLIC_2001 | walkOutdoor | justProjection | varianceMap | [1.318694186961007e-07, 0.4579757478807493]
# FLIC_2001 | walkOutdoor | justProjection | spdByRegion | [0.0, 0.3176379703015083]
# FLIC_2001 | walkOutdoor | justProjection | frq | [1.0, 59.0]
# FLIC_2002 | walkOutdoor | virtuallyFoveated | exponentMap | [0.8691896759898968, 1.740952505940204]
# FLIC_2002 | walkOutdoor | virtuallyFoveated | varianceMap | [0.004979260286143474, 0.22788923503882755]
# FLIC_2002 | walkOutdoor | virtuallyFoveated | spdByRegion | [1.5287756198528034e-07, 0.15574737578993092]
# FLIC_2002 | walkOutdoor | virtuallyFoveated | frq | [1.0, 59.0]
# FLIC_2002 | walkOutdoor | justProjection | exponentMap | [1.0312391255272924, 2.075436056187241]
# FLIC_2002 | walkOutdoor | justProjection | varianceMap | [1.1388466002102076e-06, 0.29043141807209]
# FLIC_2002 | walkOutdoor | justProjection | spdByRegion | [0.0, 0.1710720691207925]
# FLIC_2002 | walkOutdoor | justProjection | frq | [1.0, 59.0]
# FLIC_2003 | walkOutdoor | virtuallyFoveated | exponentMap | [0.3763992715032711, 1.8332304509856658]
# FLIC_2003 | walkOutdoor | virtuallyFoveated | varianceMap | [0.0033854194133333, 0.6302864828028998]
# FLIC_2003 | walkOutdoor | virtuallyFoveated | spdByRegion | [3.291806296244795e-07, 0.3719026118270606]
# FLIC_2003 | walkOutdoor | virtuallyFoveated | frq | [1.0, 59.0]
# FLIC_2003 | walkOutdoor | justProjection | exponentMap | [1.0175532574358732, 2.1061610966452404]
# FLIC_2003 | walkOutdoor | justProjection | varianceMap | [4.7489826538497175e-06, 0.6716576610980652]
# FLIC_2003 | walkOutdoor | justProjection | spdByRegion | [0.0, 0.40156859175995624]
# FLIC_2003 | walkOutdoor | justProjection | frq | [1.0, 59.0]
# FLIC_2004 | walkOutdoor | virtuallyFoveated | exponentMap | [1.1979267668417362, 1.7795628220643207]
# FLIC_2004 | walkOutdoor | virtuallyFoveated | varianceMap | [0.010721446840871594, 0.30342452689894733]
# FLIC_2004 | walkOutdoor | virtuallyFoveated | spdByRegion | [3.5020991699769214e-06, 0.18796543334516586]
# FLIC_2004 | walkOutdoor | virtuallyFoveated | frq | [1.0, 59.0]
# FLIC_2004 | walkOutdoor | justProjection | exponentMap | [0.6983835814724688, 1.9172983475463041]
# FLIC_2004 | walkOutdoor | justProjection | varianceMap | [1.6130969488151556e-07, 0.40306074600466235]
# FLIC_2004 | walkOutdoor | justProjection | spdByRegion | [0.0, 0.239759175530631]
# FLIC_2004 | walkOutdoor | justProjection | frq | [1.0, 59.0]
# FLIC_2001 | work | virtuallyFoveated | exponentMap | [0.6905150274227696, 1.88413576446733]
# FLIC_2001 | work | virtuallyFoveated | varianceMap | [0.00133057609109424, 0.13789657676542255]
# FLIC_2001 | work | virtuallyFoveated | spdByRegion | [1.5430107995480616e-07, 0.10637798006325244]
# FLIC_2001 | work | virtuallyFoveated | frq | [1.0, 59.0]
# FLIC_2001 | work | justProjection | exponentMap | [0.14336872721026556, 1.8646269922550127]
# FLIC_2001 | work | justProjection | varianceMap | [1.793346974943213e-07, 0.16202487247131478]
# FLIC_2001 | work | justProjection | spdByRegion | [0.0, 0.12257119758648083]
# FLIC_2001 | work | justProjection | frq | [1.0, 59.0]
# FLIC_2002 | work | virtuallyFoveated | exponentMap | [0.5624755813609249, 1.7084177879193747]
# FLIC_2002 | work | virtuallyFoveated | varianceMap | [0.0011440260153172414, 0.13284749381522964]
# FLIC_2002 | work | virtuallyFoveated | spdByRegion | [4.707825036522061e-09, 0.10747932582781888]
# FLIC_2002 | work | virtuallyFoveated | frq | [1.0, 59.0]
# FLIC_2002 | work | justProjection | exponentMap | [0.057202662241703416, 1.8592386210995144]
# FLIC_2002 | work | justProjection | varianceMap | [4.1610256853107896e-08, 0.13870522744671196]
# FLIC_2002 | work | justProjection | spdByRegion | [0.0, 0.11454467346829289]
# FLIC_2002 | work | justProjection | frq | [1.0, 59.0]
# FLIC_2003 | work | virtuallyFoveated | exponentMap | [0.7376431001116269, 1.718634743126782]
# FLIC_2003 | work | virtuallyFoveated | varianceMap | [0.0012532361589634498, 0.07455461223431441]
# FLIC_2003 | work | virtuallyFoveated | spdByRegion | [4.2179152324438556e-07, 0.07485154406565993]
# FLIC_2003 | work | virtuallyFoveated | frq | [1.0, 59.0]
# FLIC_2003 | work | justProjection | exponentMap | [-0.010753575801653398, 1.9691121945154353]
# FLIC_2003 | work | justProjection | varianceMap | [8.377210741378217e-08, 0.046593150731369576]
# FLIC_2003 | work | justProjection | spdByRegion | [0.0, 0.05188679278208691]
# FLIC_2003 | work | justProjection | frq | [1.0, 59.0]
# FLIC_2004 | work | virtuallyFoveated | exponentMap | [0.9533912171312215, 1.693737155716193]
# FLIC_2004 | work | virtuallyFoveated | varianceMap | [0.006154127613706569, 0.0774563028667724]
# FLIC_2004 | work | virtuallyFoveated | spdByRegion | [7.724584662253626e-07, 0.06820104694991666]
# FLIC_2004 | work | virtuallyFoveated | frq | [1.0, 59.0]
# FLIC_2004 | work | justProjection | exponentMap | [0.2481346917338403, 1.9483511498871329]
# FLIC_2004 | work | justProjection | varianceMap | [8.192041374080383e-08, 0.08320850191568409]
# FLIC_2004 | work | justProjection | spdByRegion | [0.0, 0.07054147444537444]
# FLIC_2004 | work | justProjection | frq | [1.0, 59.0]
# Activity: chat | Graph Type: exponentMap | Bounds: [-0.00860714  1.92683584]
# Activity: chat | Graph Type: varianceMap | Bounds: [5.40148066e-09 1.91876305e-01]
# Activity: chat | Graph Type: spdByRegion | Bounds: [1.00000000e-08 4.01568592e-01]
# Activity: chat | Graph Type: frq | Bounds: [ 1. 59.]
# Activity: sitBiopond | Graph Type: exponentMap | Bounds: [2.66650907e-15 1.93395240e+00]
# Activity: sitBiopond | Graph Type: varianceMap | Bounds: [4.80690971e-09 3.26014245e-01]
# Activity: sitBiopond | Graph Type: spdByRegion | Bounds: [1.00000000e-08 4.01568592e-01]
# Activity: sitBiopond | Graph Type: frq | Bounds: [ 1. 59.]
# Activity: walkBiopond | Graph Type: exponentMap | Bounds: [-5.54498705e-16  2.17879978e+00]
# Activity: walkBiopond | Graph Type: varianceMap | Bounds: [1.15816697e-09 3.88954151e-01]
# Activity: walkBiopond | Graph Type: spdByRegion | Bounds: [1.00000000e-08 4.01568592e-01]
# Activity: walkBiopond | Graph Type: frq | Bounds: [ 1. 59.]
# Activity: walkIndoor | Graph Type: exponentMap | Bounds: [1.05240863e-15 2.03117246e+00]
# Activity: walkIndoor | Graph Type: varianceMap | Bounds: [1.04236334e-08 1.98582569e-01]
# Activity: walkIndoor | Graph Type: spdByRegion | Bounds: [1.00000000e-08 4.01568592e-01]
# Activity: walkIndoor | Graph Type: frq | Bounds: [ 1. 59.]
# Activity: walkOutdoor | Graph Type: exponentMap | Bounds: [0.37639927 2.1061611 ]
# Activity: walkOutdoor | Graph Type: varianceMap | Bounds: [1.31869419e-07 6.71657661e-01]
# Activity: walkOutdoor | Graph Type: spdByRegion | Bounds: [1.00000000e-08 4.01568592e-01]
# Activity: walkOutdoor | Graph Type: frq | Bounds: [ 1. 59.]
# Activity: work | Graph Type: exponentMap | Bounds: [-0.01075358  1.96911219]
# Activity: work | Graph Type: varianceMap | Bounds: [4.16102569e-08 1.62024872e-01]
# Activity: work | Graph Type: spdByRegion | Bounds: [1.00000000e-08 4.01568592e-01]
# Activity: work | Graph Type: frq | Bounds: [ 1. 59.]
# Processing Activities:   0%|          | 0/6 [00:00<?, ?it/s]
# HELLO FROM MATLAB. These are the bounds before they get send to be plotted
# chat
#    -0.0086    1.9268
#
#     0.0000    0.1919
#
#     0.0000    0.4016
#
#      1    59
#
# HERE ARE THE CLIM VALS
#    -0.0086    1.9268
#
# SHOULD BE OUTPUTTING TO THIS PATH
# /Users/zacharykelly/Aguirre-Brainard Lab Dropbox/Zachary Kelly/FLIC_analysis/lightLogger/NEWscriptedIndoorOutdoorVideos2026/acrossSubjects/chat/chat_virtuallyFoveated_exponentMapAcrossSubjects.pdf
# HELLO FROM MATLAB. These are the bounds before they get send to be plotted
# sitBiopond
#     0.0000    1.9340
#
#     0.0000    0.3260
#
#     0.0000    0.4016
#
#      1    59
#
# HERE ARE THE CLIM VALS
#     0.0000    1.9340
#
# SHOULD BE OUTPUTTING TO THIS PATH
# /Users/zacharykelly/Aguirre-Brainard Lab Dropbox/Zachary Kelly/FLIC_analysis/lightLogger/NEWscriptedIndoorOutdoorVideos2026/acrossSubjects/sitBiopond/sitBiopond_virtuallyFoveated_exponentMapAcrossSubjects.pdf
# HELLO FROM MATLAB. These are the bounds before they get send to be plotted
# walkBiopond
#    -0.0000    2.1788
#
#     0.0000    0.3890
#
#     0.0000    0.4016
#
#      1    59
#
# HERE ARE THE CLIM VALS
#    -0.0000    2.1788
#
# SHOULD BE OUTPUTTING TO THIS PATH
# /Users/zacharykelly/Aguirre-Brainard Lab Dropbox/Zachary Kelly/FLIC_analysis/lightLogger/NEWscriptedIndoorOutdoorVideos2026/acrossSubjects/walkBiopond/walkBiopond_virtuallyFoveated_exponentMapAcrossSubjects.pdf
# HELLO FROM MATLAB. These are the bounds before they get send to be plotted
# walkIndoor
#     0.0000    2.0312
#
#     0.0000    0.1986
#
#     0.0000    0.4016
#
#      1    59
#
# HERE ARE THE CLIM VALS
#     0.0000    2.0312
#
# SHOULD BE OUTPUTTING TO THIS PATH
# /Users/zacharykelly/Aguirre-Brainard Lab Dropbox/Zachary Kelly/FLIC_analysis/lightLogger/NEWscriptedIndoorOutdoorVideos2026/acrossSubjects/walkIndoor/walkIndoor_virtuallyFoveated_exponentMapAcrossSubjects.pdf
# HELLO FROM MATLAB. These are the bounds before they get send to be plotted
# walkOutdoor
#     0.3764    2.1062
#
#     0.0000    0.6717
#
#     0.0000    0.4016
#
#      1    59
#
# HERE ARE THE CLIM VALS
#     0.3764    2.1062
#
# SHOULD BE OUTPUTTING TO THIS PATH
# /Users/zacharykelly/Aguirre-Brainard Lab Dropbox/Zachary Kelly/FLIC_analysis/lightLogger/NEWscriptedIndoorOutdoorVideos2026/acrossSubjects/walkOutdoor/walkOutdoor_virtuallyFoveated_exponentMapAcrossSubjects.pdf
# HELLO FROM MATLAB. These are the bounds before they get send to be plotted
# work
#    -0.0108    1.9691
#
#     0.0000    0.1620
#
#     0.0000    0.4016
#
#      1    59
#
# HERE ARE THE CLIM VALS
#    -0.0108    1.9691
#
# SHOULD BE OUTPUTTING TO THIS PATH
# /Users/zacharykelly/Aguirre-Brainard Lab Dropbox/Zachary Kelly/FLIC_analysis/lightLogger/NEWscriptedIndoorOutdoorVideos2026/acrossSubjects/work/work_virtuallyFoveated_exponentMapAcrossSubjects.pdf
