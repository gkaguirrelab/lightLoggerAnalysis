# %%
import world_util
import importlib
import numpy as np

# %%
importlib.reload(world_util)
image: np.ndarray = np.zeros((480, 640), dtype=np.uint8)
world_util.generate_fielding_function(np.zeros((480, 640)), )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 importlib.reload(world_util)
# ----> 2 world_util.generate_fielding_function(np.zeros(480, 640))
#
# TypeError: Cannot interpret '640' as a data type
