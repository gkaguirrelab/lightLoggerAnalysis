# %%
# In this notebook, I will outline the steps to virtually foveate a video

# %%
# 1. Generate a playable video if you have not done so already. This should be a grayscale, color weight applied video

# %%
# 2. Extract the gaze target locations from the gaze calibration video if you have not done so already

# %%
# 3. Virtually foveate the video
